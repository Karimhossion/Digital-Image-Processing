# %%
import numpy as np
import PIL.Image as Image
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %%
data = loadmat("Indian_pines.mat")
img = data['indian_pines']

# %%
print(img)
# Out:
# [[[3172 4142 4506 ... 1020 1020 1005]
#   [2580 4266 4502 ... 1029 1020 1000]
#   [3687 4266 4421 ... 1030 1016 1009]
#   ...
#   [2570 3890 4320 ... 1021 1015 1025]
#   [3170 4130 4320 ... 1024 1020 1011]
#   [3172 3890 4316 ... 1034 1016 1015]]
#
#  [[2576 4388 4334 ... 1030 1006 1015]
#   [2747 4264 4592 ... 1039 1015 1020]
#   [2750 4268 4423 ... 1026 1015 1020]
#   ...
#   [3859 4512 4605 ... 1035 1015  996]
#   [3686 4264 4690 ... 1012 1020 1014]
#   [2744 4268 4597 ... 1019 1016 1010]]
#
#  [[2744 4146 4416 ... 1029 1025 1010]
#   [2576 4389 4416 ... 1021 1011 1000]
#   [2744 4273 4420 ... 1033 1010 1014]
#   ...
#   [2570 4266 4509 ... 1025 1010 1005]
#   [2576 4262 4496 ... 1029 1020 1005]
#   [2742 4142 4230 ... 1025 1011 1010]]
#
#  ...
#
#  [[3324 3728 4002 ... 1004 1004 1000]
#   [2983 3604 3829 ... 1013 1008  995]
#   [2988 3612 3913 ... 1001 1004 1003]
#   ...
#   [2564 4115 4103 ... 1005 1013 1009]
#   [2730 4111 4103 ... 1013 1004 1004]
# ...

# %%
print(img[0:50,0:45,219].shape)
# Out:
# (50, 45)

# %%
plt.imshow(img[:, :, 219], cmap="gray")
plt.show()

# %%
plt.imshow(img[0:50,0:45,219],cmap="gray")
plt.show()

# %%
print(img.shape)
# Out:
# (145, 145, 220)

# %%
plt.imshow(img[0:40, 0:25, 219], cmap="gray")
plt.title("Indians Pins")
plt.show()

# %%
img = Image.open("images/hy.jpg")
img = np.array(img)

# %%
H, W, C = img.shape
print(H ,W, C)

plt.title("RGB")
plt.imshow(img)
plt.show()
# Out:
# 310 310 3

# %%
print(img[:, :, 0].shape)
print(592/2,1080/2)
# Out:
# (310, 310)
# 296.0 540.0

# %%
red = img[:, :, 0]
green = img[:, :, 1]
blue = img[:, :, 2]

# %%
#red = img[0:296, 0:540, 0]
blue=img[296:, 540:, 2]

# %%
fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(20,15))

axes[0].set_title("RED")
axes[0].imshow(red, cmap="gray")

axes[1].set_title("Green")
axes[1].imshow(green, cmap="gray")

axes[2].set_title("Blue")
axes[2].imshow(blue, cmap="gray")


plt.show()
