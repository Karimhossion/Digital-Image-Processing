# %%
import math
import numpy as np
import PIL.Image as Image
import matplotlib.pyplot as plt

# %%
img = Image.open("images/vu.jpg").convert("L")
img = np.array(img)

H,W = img.shape

plt.title("Grayscale")
plt.imshow(img, cmap="gray")
plt.show()

# %%
sobel_vertical_kernel=np.array(
    [
        [-1, 0, 1],
        [-2, 0, 2],
        [-1, 0, 1]
    ]
)
sobel_horizontal_kernel

# %%
vertical_edges=np.zeros(H,W)
